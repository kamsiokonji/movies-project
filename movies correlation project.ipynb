# %% [markdown]
# In this project, we'll be using a Movies dataset to check the correlation between the Budget and the Gross Earnings of the movies.

# %%
# import libraries
import matplotlib
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
from matplotlib.pyplot import figure
matplotlib.rcParams["figure.figsize"] = (
    12,
    8,
)  # adjusts the configuration of the plots we will make

pd.options.mode.chained_assignment = None

# %%
# read the data
movies = pd.read_csv("../data/raw/movies.csv")
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# locating missing data
for col in movies.columns:
    num_missing = np.sum(movies[col].isnull())
    print("{} {}".format(col, num_missing))
# Out:
# name 0
# rating 77
# genre 0
# year 0
# released 2
# score 3
# votes 3
# director 0
# writer 3
# star 1
# country 3
# budget 2171
# gross 189
# company 17
# runtime 4

# %%
# drop missing data
movies_new = movies.dropna()
movies_new
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# inspecting the data types of each field
movies_new.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# changing budget, gross, runtime and votes from float to int
movies_new["budget"] = movies_new["budget"].astype("int64")
movies_new["gross"] = movies_new["gross"].astype("int64")
movies_new["runtime"] = movies_new["runtime"].astype("int64")
movies_new["votes"] = movies_new["votes"].astype("int64")
movies_new.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# extracting the year from released column
movies_new["yearcorrect"] = (
    movies_new["released"].str.extract(pat="([0-9]{4})").astype("int64")
)

movies_new.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# ...

# %%
# sorting the data by gross in descending order
movies_new.sort_values(by="gross", inplace=True, ascending=False)
movies_new.head()
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# ...

# %%
# drop duplicate values
movies_new.drop_duplicates()
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score    votes             director  \
# ...

# %%
# drop the year column
movies_new.drop(columns='year', axis=1, inplace=True)
movies_new.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# ...

# %%
# renaming the yearcorrect column
movies_new.rename(columns={"yearcorrect": "year"}, inplace=True)
movies_new.head()
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# ...

# %%
# Correlation between budget and gross using scatter plot
plt.scatter(x=movies_new['budget'], y=movies_new['gross'])
plt.title('Budget vs. Gross Earnings')
plt.xlabel('Budget For Film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# plot budget vs gross using seaborn
sns.regplot(
    x="budget",
    y="gross",
    data=movies_new,
    scatter_kws={"color": "red"},
    line_kws={"color": "blue"},
)
# Out:
# <AxesSubplot: xlabel='budget', ylabel='gross'>

# %% [markdown]
# A Pearson correlation coefficient was computed to assess the linear relationship between Budget and Gross Earnings.

# %%
# checking correlation using pearson method
correlation_matrix = movies_new.corr(method='pearson', numeric_only=True)
correlation_matrix
# Out:
#             score     votes    budget     gross   runtime      year
# score    1.000000  0.474256  0.072001  0.222556  0.414068  0.061923
# votes    0.474256  1.000000  0.439675  0.614751  0.352303  0.203098
# budget   0.072001  0.439675  1.000000  0.740247  0.318695  0.320312
# gross    0.222556  0.614751  0.740247  1.000000  0.275796  0.268721
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000  0.075294
# year     0.061923  0.203098  0.320312  0.268721  0.075294  1.000000

# %%
# visualizing correlation using heatmap
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix For Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
# numerizing all the data to visualize in the heatmap using for loop
movies_new_numerized = movies_new
for col_name in movies_new_numerized.columns:
    if movies_new_numerized[col_name].dtype == "object":
        movies_new_numerized[col_name] = movies_new_numerized[col_name].astype(
            "category"
        )
        movies_new_numerized[col_name] = movies_new_numerized[col_name].cat.codes

movies_new_numerized.head()
# Out:
#       name  rating  genre  released  score    votes  director  writer  star  \
# 5445   386       5      0       527    7.8  1100000       785    1263  1534
# 7445   388       5      0       137    8.4   903000       105     513  1470
# 3045  4909       5      6       534    7.8  1100000       785    1263  1073
# 6663  3643       5      0       529    7.8   876000       768    1806   356
# 7244   389       5      0       145    8.4   897000       105     513  1470
#
#       country     budget       gross  company  runtime  year
# 5445       47  237000000  2847246203     1382      162  2009
# 7445       47  356000000  2797501328      983      181  2019
# 3045       47  200000000  2201647264     1382      194  1997
# 6663       47  245000000  2069521700      945      138  2015
# 7244       47  321000000  2048359754      983      149  2018

# %%
# correlating the values using pearson method
correlation_matrix = movies_new_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix For Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
movies_new_numerized.corr()
# Out:
#               name    rating     genre  released     score     votes  \
# name      1.000000 -0.029234  0.010996 -0.006152  0.014450  0.012615
# rating   -0.029234  1.000000  0.147796  0.018083  0.065983  0.006031
# genre     0.010996  0.147796  1.000000  0.022142  0.035106 -0.135990
# released -0.006152  0.018083  0.022142  1.000000  0.045874  0.028833
# score     0.014450  0.065983  0.035106  0.045874  1.000000  0.474256
# votes     0.012615  0.006031 -0.135990  0.028833  0.474256  1.000000
# director  0.015246  0.014656 -0.008553  0.002308  0.005413 -0.010376
# writer    0.012880 -0.003149  0.017578  0.008072  0.012843 -0.005316
# star     -0.006882  0.009196  0.003341  0.015706  0.007296 -0.017638
# country  -0.025490  0.008230 -0.009164 -0.017228 -0.043051  0.041551
# budget    0.023392 -0.203946 -0.368523  0.019952  0.072001  0.439675
# gross     0.005639 -0.181906 -0.244101  0.008501  0.222556  0.614751
# company   0.021697 -0.092357 -0.071334 -0.002407  0.020656  0.118470
# ...

# %%
correlation_mat = movies_new_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name  name        1.000000
#       rating     -0.029234
#       genre       0.010996
#       released   -0.006152
#       score       0.014450
#                     ...
# year  budget      0.320312
#       gross       0.268721
#       company    -0.018806
#       runtime     0.075294
#       year        1.000000
# Length: 225, dtype: float64

# %%
# sorting the corr pairs
sorted_corr_pairs = corr_pairs.sort_values()
sorted_corr_pairs
# Out:
# budget    genre      -0.368523
# genre     budget     -0.368523
#           gross      -0.244101
# gross     genre      -0.244101
# rating    budget     -0.203946
#                         ...
# released  released    1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# runtime   runtime     1.000000
# year      year        1.000000
# Length: 225, dtype: float64

# %%
# checking for categories with high correlation
high_corr = sorted_corr_pairs[(sorted_corr_pairs) > 0.5]
high_corr
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
# budget    gross       0.740247
# gross     budget      0.740247
# name      name        1.000000
# writer    writer      1.000000
# company   company     1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# runtime   runtime     1.000000
# year      year        1.000000
# dtype: float64

# %% [markdown]
# There was a positive correlation between the Budget and Gross Earnings of the Movies.
# Additionally, we can also see that there is a positive correlation between the Votes category and the Gross Earning category.
